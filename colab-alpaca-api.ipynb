# %% [markdown]
# # Install the requirements

# %%
# !pip install -q datasets loralib sentencepiece
# !pip uninstall transformers
# !pip install -q git+https://github.com/zphang/transformers@c3dc391
# !pip -q install git+https://github.com/huggingface/peft.git
# !pip -q install bitsandbytes
# !pip -q install flask

# %% [markdown]
# # Download the script

# %%
# !wget https://raw.githubusercontent.com/MarcelloCarboni/alpaca-api/main/alpaca-api.py

# %% [markdown]
# # Download Ngrok and add your authtoken
# **Add your token after 'add-authtoken'**
#
# If you're not sure how to get your token, register an account on [ngrok](ngrok.com) and a token will be generated for you.

# %%
# !wget https://bin.equinox.io/c/bNyj1mQVY4c/ngrok-v3-stable-linux-amd64.tgz
# !tar -xzvf ngrok-v3-stable-linux-amd64.tgz

# !./ngrok config add-authtoken

# %% [markdown]
# # Start the tunnel

# %%
get_ipython().system_raw('./ngrok http 5000 &')

# %% [markdown]
# # Get the link to the API

# %%
# !curl -s http://localhost:4040/api/tunnels | python3 -c "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"

# %% [markdown]
# # Start the main application

# %%
# !python3 alpaca-api.py
